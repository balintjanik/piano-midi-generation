# %%
# Imports
import torch
import torch.nn as nn
from torch.utils.data import Dataset
import numpy as np
import os
from src.utils.preprocess_utils import midi_to_note_indices, notes_to_one_hot
from src.utils.ml_utils import create_dataloaders, train_model, test_model, plot_metrics

# %%
# Define dataset
class MidiDataset(Dataset):
    def __init__(self, data_dir, sequence_length=50):
        self.data_dir = data_dir
        self.sequence_length = sequence_length
        self.file_names = [f for f in os.listdir(data_dir) if f.endswith('.mid') or f.endswith('.midi')]

    def __len__(self):
        return len(self.file_names)

    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = os.path.join(self.data_dir, file_name)
        
        try:
            data = midi_to_note_indices(file_path)
            
            if len(data) < self.sequence_length:
                raise ValueError(f"File {file_name} is too short for sequence length {self.sequence_length}")
            
            # Pick a random starting index and crop the data to sequence_length
            start_idx = np.random.randint(0, len(data) - self.sequence_length + 1)
            cropped_data = data[start_idx:start_idx + self.sequence_length]

            x = cropped_data[:-1] # Input
            y = cropped_data[1:] # "Label"
            y = notes_to_one_hot(y, 0, 84)

            return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)
        except Exception as e:
            print(f"Error processing {file_name}: {e}")
            # If the file is invalid or too short, retry with another random file
            new_idx = np.random.randint(0, len(self.file_names))
            return self.__getitem__(new_idx)

dataset_sequence_length = 25
dataset = MidiDataset(data_dir='data/midis', sequence_length=dataset_sequence_length)

# %%
# Get dataloaders with specified params from ml_utils
dataloader_train, dataloader_val, dataloader_test = create_dataloaders(dataset=dataset, batch_size=32, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15, shuffle=True)

# %%
# Define model architecture
class TransformerModel(nn.Module):
    def __init__(self, vocab_size, embedding_size, num_heads, hidden_size, num_layers, dropout=0.2):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.transformer = nn.Transformer(
            d_model=embedding_size,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            dim_feedforward=hidden_size,
            dropout=dropout,
            batch_first=True
        )
        self.fc = nn.Linear(embedding_size, vocab_size)

    def forward(self, x):
        # x: [batch_size, sequence_length]
        x = x.long()
        embedded = self.embedding(x)  # [batch_size, sequence_length, embedding_size]
        transformer_out = self.transformer.encoder(embedded)  # [batch_size, sequence_length, embedding_size]
        output = self.fc(transformer_out)  # [batch_size, sequence_length, vocab_size]
        return output

vocab_size = 85  # Number of possible notes
embedding_size = 32  # Dimension of embedding vectors
num_heads = 4  # Number of attention heads
hidden_size = 128  # Size of feedforward layers in transformer
num_layers = 3  # Number of transformer encoder layers
dropout = 0.2  # Dropout rate

model = TransformerModel(vocab_size, embedding_size, num_heads, hidden_size, num_layers, dropout)

# %%
# Train model from ml_utils
best_model, history = train_model(
    model=model,
    dataloaders={"train": dataloader_train, "val": dataloader_val},
    task_type="multiclass",
    n_epochs=15,
    learning_rate=0.001,
    device="cuda"
)
(train_losses, val_losses, train_accuracy, val_accuracy) = history
plot_metrics(train_losses, val_losses, train_accuracy, val_accuracy)
# Out:
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Epoch 0: Train Loss=0.8940, Val Loss=0.8808, Train Acc=0.0094, Val Acc=0.0143
#     Early stopping: Best model updated.
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Epoch 1: Train Loss=0.8817, Val Loss=0.8765, Train Acc=0.0161, Val Acc=0.0168
#     Early stopping: Best model updated.
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Epoch 2: Train Loss=0.8778, Val Loss=0.8733, Train Acc=0.0190, Val Acc=0.0265
#     Early stopping: Best model updated.
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Epoch 3: Train Loss=0.8757, Val Loss=0.8721, Train Acc=0.0228, Val Acc=0.0253
#     Early stopping: Best model updated.
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Epoch 4: Train Loss=0.8750, Val Loss=0.8710, Train Acc=0.0225, Val Acc=0.0257
#     Early stopping: Best model updated.
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Epoch 5: Train Loss=0.8733, Val Loss=0.8704, Train Acc=0.0260, Val Acc=0.0347
#     Early stopping: Best model updated.
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Epoch 6: Train Loss=0.8728, Val Loss=0.8697, Train Acc=0.0255, Val Acc=0.0322
#     Early stopping: Best model updated.
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Epoch 7: Train Loss=0.8719, Val Loss=0.8691, Train Acc=0.0277, Val Acc=0.0320
#     Early stopping: Best model updated.
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Epoch 8: Train Loss=0.8721, Val Loss=0.8693, Train Acc=0.0274, Val Acc=0.0322
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Epoch 9: Train Loss=0.8716, Val Loss=0.8687, Train Acc=0.0303, Val Acc=0.0356
#     Early stopping: Best model updated.
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Epoch 10: Train Loss=0.8713, Val Loss=0.8696, Train Acc=0.0312, Val Acc=0.0342
# Error processing Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid: File Stahl, William C., Golden Bell Waltz, gmrKI53VUVQ.mid is too short for sequence length 25
# Error processing Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid: File Antico, Andrea, Per dolor mi bagno, uFY9NWLIpkc.mid is too short for sequence length 25
# Error processing Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid: File Gumpelzhaimer, Adam, Was mein Gott will, das g'scheh allzeit, BTQegBbW13A.mid is too short for sequence length 25
# Epoch 11: Train Loss=0.8705, Val Loss=0.8687, Train Acc=0.0315, Val Acc=0.0351
# Early stopping triggered. Restoring best model.

# %%
# Test model from ml_utils
test_model(best_model, dataloader_test, nn.CrossEntropyLoss(), task_type="multiclass", device="cuda")
# Out:
# Error processing Ferrari, Carlotta, D.E.A.TH., TVvpJ0ya_tQ.mid: File Ferrari, Carlotta, D.E.A.TH., TVvpJ0ya_tQ.mid is too short for sequence length 25
# Test metrics - Loss: 0.8701, Accuracy: 0.0356
# (np.float64(0.8701357409065845), np.float64(0.035620211751437654))

# %%
# Save model
from datetime import datetime

timestamp = datetime.today().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'weights/model_3/{timestamp}_e{embedding_size}_nh{num_heads}_h{hidden_size}_l{num_layers}_sl{dataset_sequence_length}'

torch.save(best_model, filename)
